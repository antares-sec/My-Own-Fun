# %%
import tweepy
import pandas as pd

# %%
consumer_key = "qemLnSdu7MwdGqtpoUQpRyFJk" #Your API/Consumer key
consumer_secret = "Wgz4il8YbO6xmhYnm5z7v6X7QARBfBo8wD4VrGuNmZau4H0rAI" #Your API/Consumer Secret Key
access_token = "1580637458479214592-KozFlnV2EmA8piWBt3UiVGt70gtX3g"    #Your Access token key
access_token_secret = "8Vw9XvxmBtbYhIpHpgA7Q7jZD0KTmZQJVrGEtNQpyxH1w" #Your Access token Secret key

#Pass in our twitter API authentication key
auth = tweepy.OAuth1UserHandler(
    consumer_key, consumer_secret,
    access_token, access_token_secret
)

# %%
#Instantiate the tweepy API
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
search_query = "#telkom since:2022-09-01 "

# %%
# search_query = "#telkom since:2022-09-01 until:2022-09-30"

# %%
#The number of tweets we want to retrieved from the search
tweets = api.search_tweets(q=search_query, count=1000)
# Out:
# /home/antares/Documents/anka/Job/Hidup/MachineLearning/env/lib/python3.12/site-packages/tweepy/api.py:301: SyntaxWarning: invalid escape sequence '\['
#   """home_timeline(*, count, since_id, max_id, trim_user, \
# /home/antares/Documents/anka/Job/Hidup/MachineLearning/env/lib/python3.12/site-packages/tweepy/api.py:341: SyntaxWarning: invalid escape sequence '\['
#   """mentions_timeline(*, count, since_id, max_id, trim_user, \
# /home/antares/Documents/anka/Job/Hidup/MachineLearning/env/lib/python3.12/site-packages/tweepy/api.py:376: SyntaxWarning: invalid escape sequence '\['
#   """user_timeline(*, user_id, screen_name, since_id, count, max_id, \
# /home/antares/Documents/anka/Job/Hidup/MachineLearning/env/lib/python3.12/site-packages/tweepy/api.py:426: SyntaxWarning: invalid escape sequence '\['
#   """get_favorites(*, user_id, screen_name, count, since_id, max_id, \
# ...

# %%
no_of_tweets =1000

# %%
 #The number of tweets we want to retrieved from the search
tweets = api.search_tweets(q=search_query, count=no_of_tweets)
#Pulling Some attributes from the tweet
attributes_container = [[tweet.user.name, tweet.created_at, tweet.favorite_count, tweet.source,  tweet.text] for tweet in tweets]

#Creation of column list to rename the columns in the dataframe
columns = ["User", "Date Created", "Number of Likes", "Source of Tweet", "Tweet"]
#Creation of Dataframe
tweets_df = pd.DataFrame(attributes_container, columns=columns)
# Out:
#   File "<ipython-input-10-3bf80c62dc9d>", line 2
#     tweets = api.search_tweets(q=search_query, count=no_of_tweets)
#     ^
# IndentationError: unexpected indent

# %%
search_query = "#telkom"

# %%
no_of_tweets =1000

# %%
#The number of tweets we want to retrieved from the search
tweets = api.search_tweets(q=search_query, count=no_of_tweets)
#Pulling Some attributes from the tweet
attributes_container = [[tweet.user.name, tweet.created_at, tweet.favorite_count, tweet.source,  tweet.text] for tweet in tweets]
#Creation of column list to rename the columns in the dataframe
columns = ["User", "Date Created", "Number of Likes", "Source of Tweet", "Tweet"]
#Creation of Dataframe
tweets_df = pd.DataFrame(attributes_container, columns=columns)
# Out:
#   File "<ipython-input-13-6cb33f7b0642>", line 2
#     tweets = api.search_tweets(q=search_query, count=no_of_tweets)
#     ^
# IndentationError: unexpected indent

# %%
tweets = api.user_timeline(screen_name=username, count=no_of_tweets)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-5964f23b73a3> in <cell line: 1>()
# ----> 1 tweets = api.user_timeline(screen_name=username, count=no_of_tweets)
#
# NameError: name 'username' is not defined

# %%
tweets = api.search_tweets(q=search_query, count=no_of_tweets)
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# <ipython-input-15-247ce970f31f> in <cell line: 1>()
# ----> 1 tweets = api.search_tweets(q=search_query, count=no_of_tweets)
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      31         @functools.wraps(method)
#      32         def wrapper(*args, **kwargs):
# ---> 33             return method(*args, **kwargs)
#      34         wrapper.pagination_mode = mode
#      35         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# ...
