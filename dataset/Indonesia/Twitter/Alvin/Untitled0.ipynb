# %%
# !pip3 install twint
import twint

c = twint.Config()
c.Search = "#telkom"
c.Limit = 100

twint.run.Search(c)
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 653.6/653.6 kB 10.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.9/393.9 kB 15.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 3.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.7/288.7 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.3/53.3 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 4.6 MB/s eta 0:00:00
# ...
#   Created wheel for twint: filename=twint-2.1.20-py3-none-any.whl size=33911 sha256=5751231c849932117241708cd2f58b4d3cd9d82f339f97d9989e27a137a0f7e7
#   Stored in directory: /root/.cache/pip/wheels/48/d2/f5/7a71ea8b6788b85fac82abf4ef84dac03562571f695c3b8f77
# ...

# %%
c = twint.Config()
c.Search = "#telkom"
c.Limit = 10

twint.run.Search(c)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-32e6724db764> in <cell line: 5>()
#       3 c.Limit = 10
#       4
# ----> 5 twint.run.Search(c)
#
# /usr/local/lib/python3.10/dist-packages/twint/run.py in Search(config, callback)
#     325     config.Profile = False
#     326     config.Profile_full = False
# --> 327     run(config, callback)
#     328     if config.Pandas_au:
#     329         storage.panda._autoget("tweet")
#
# /usr/local/lib/python3.10/dist-packages/twint/run.py in run(config, callback)
#     224         raise
#     225
# --> 226     get_event_loop().run_until_complete(Twint(config).main(callback))
#     227
#     228 def Favorites(config):
#
# /usr/lib/python3.10/asyncio/base_events.py in run_until_complete(self, future)
#     620         """
#     621         self._check_closed()
# --> 622         self._check_running()
#     623
# ...

# %%
import twint

# Configure
c = twint.Config()
c.Search = "covid vaccin"
c.Lang = "fr"
c.Geo = "48.880048,2.385939,5km"
c.Limit = 300
c.Output = "./test.json"
c.Store_json = True

# Run
twint.run.Search(c)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-3efc9f3c35fd> in <cell line: 13>()
#      11
#      12 # Run
# ---> 13 twint.run.Search(c)
#
# /usr/local/lib/python3.10/dist-packages/twint/run.py in Search(config, callback)
#     325     config.Profile = False
#     326     config.Profile_full = False
# --> 327     run(config, callback)
#     328     if config.Pandas_au:
#     329         storage.panda._autoget("tweet")
#
# /usr/local/lib/python3.10/dist-packages/twint/run.py in run(config, callback)
#     224         raise
#     225
# --> 226     get_event_loop().run_until_complete(Twint(config).main(callback))
#     227
#     228 def Favorites(config):
#
# /usr/lib/python3.10/asyncio/base_events.py in run_until_complete(self, future)
#     620         """
#     621         self._check_closed()
# --> 622         self._check_running()
#     623
# ...
